# %%
# !pip install wikipedia
# !pip install beautifulsoup4
# !pip install winshell
# !pip install feedparser
# !pip install ecapture

# %%
import speech_recognition as sr
import pyttsx3
import pyaudio
import webbrowser as web
import os

# %%
# Initialize the recognizer
r = sr.Recognizer()

# Function to convert text to speech
def SpeakText(command):
    
    # Initialise the engine
    engine = pyttsx3.init()
    engine.say(command)
    engine.runAndWait()

# %%
# Use Microphone as a source for input
with sr.Microphone() as source2:
    SpeakText("Silence please, calibrating background noise")
    r.adjust_for_ambient_noise(source2, duration = 2)
    SpeakText("Calibrated, now speak...")
    
    # Listen's for the user's input
    audio2 = r.listen(source2)
    
    # Using google to recognize audio
    MyText = r.recognize_google(audio2)
    MyText = MyText.lower()
    
    print("Did you say " + MyText + "?")
    SpeakText(MyText)

# %%
if __name__ == "__main__":
    path = "C:/Program Files (x86)/Microsoft/Edge/Application/msedge.exe %s"
    
    r = sr.Recognizer()
    with sr.Microphone() as source:
        r.adjust_for_ambient_noise(source)
        
        SpeakText("Say Something")
        
        audio = r.listen(source)
        
        print("Recognizing now...")
        
        try:
            dest = r.recognize_google(audio)
            print("You've said: "+ dest)
            
            web.get(path).open(dest)
        except Exception as e:
            print("Error " + str(e))

# %%
import subprocess
import pyttsx3
import tkinter
import json
import random
import operator
import speech_recognition as sr
import datetime
import wikipedia
import webbrowser
import os
import winshell
import feedparser
import smtplib
import ctypes
import time
import requests
import shutil
from ecapture import ecapture as ec
from bs4 import BeautifulSoup
import win32com.client as wincl
from urllib.request import urlopen

engine = pyttsx3.init('sapi5')
voices = engine.getProperty('voices')
engine.setProperty('voice', voices[1].id)

# %%
def speak(audio):
    engine.say(audio)
    engine.runAndWait()
 
def wishMe():
    hour = int(datetime.datetime.now().hour)
    if hour>= 0 and hour<12:
        speak("Good Morning Boss !")
  
    elif hour>= 12 and hour<18:
        speak("Good Afternoon Boss!")   
  
    else:
        speak("Good Evening Boss!")  
  
    assname =("Friday")
    speak("I am your Assistant")
    speak(assname)
     
 
def username():
    speak("What should i call you Boss")
    uname = takeCommand()
    speak("Hello Sir!")
    speak(uname)
    columns = shutil.get_terminal_size().columns
     
    speak("How can I help you?")
 
def takeCommand():
     
    r = sr.Recognizer()
     
    with sr.Microphone() as source:
         
        print("Listening...")
        r.pause_threshold = 1
        audio = r.listen(source)
  
    try:
        print("Recognizing...")    
        query = r.recognize_google(audio, language ='en-in')
        print(f"User said: {query}\n")
  
    except Exception as e:
        print(e)    
        print("Unable to Recognize your voice.")  
        return "None"
     
    return query
  
def sendEmail(to, content):
    server = smtplib.SMTP('smtp.gmail.com', 587)
    server.ehlo()
    server.starttls()
     
    # Enable low security in gmail
    server.login('your email id', 'your email password')
    server.sendmail('your email id', to, content)
    server.close()

# %%
if __name__ == '__main__':
    clear = lambda: os.system('cls')
     
    # This Function will clean any
    # command before execution of this python file
    clear()
    wishMe()
    username()
     
    while True:
         
        query = takeCommand()
         
        # All the commands said by user will be 
        # stored here in 'query' and will be 
        # recognition of command
        if 'wikipedia' in query:
            speak('Searching Wikipedia...')
            query = query.replace("wikipedia", "")
            results = wikipedia.summary(query, sentences = 3)
            speak("According to Wikipedia")
            print(results)
            speak(results)
 
        elif 'open youtube' in query:
            speak("Opening Youtube\n")
            webbrowser.open("youtube.com")
 
        elif 'open google' in query:
            speak("You're now on Google\n")
            webbrowser.open("google.com")
 
        elif 'open stackoverflow' in query:
            speak("Here you go to Stack Over flow.Happy coding")
            webbrowser.open("stackoverflow.com")   
 
        elif 'play a movie' in query or "open movies folder" in query:
            speak("On it!")
            movie_dir = "D:\Movies"
            movies = os.listdir(movie_dir)
            print(movies)    
            random = os.startfile(os.path.join(movie_dir, movies[1]))
 
        elif 'the time' in query:
            strTime = datetime.datetime.now().strftime("% H:% M:% S")    
            speak(f"Sir, the time is {strTime}")
 
        elif 'open cyberpunk' in query:
            codePath = r"E:\Cyberpunk 2077\bin\x64\Cyberpunk2077.exe"
            os.startfile(Path)
 
        elif 'fine' in query or "good" in query:
            speak("It's good to know that your fine")
 
        elif "change my name to" in query:
            query = query.replace("change my name to", "")
            assname = query
 
        elif "change name" in query:
            speak("What would you like to call me, Sir ")
            assname = takeCommand()
            speak("Thanks for naming me")
 
        elif "what's your name" in query or "What is your name" in query:
            speak("My friends call me")
            speak(assname)
            print("My friends call me", assname)
 
        elif 'exit' in query:
            speak("Thanks for giving me your time")
            exit()
 
        elif "who made you" in query or "who created you" in query: 
            speak("I have been created by Hadi Badri.")
             
        elif "calculate" in query: 
             
            app_id = "Wolframalpha api id"
            client = wolframalpha.Client(app_id)
            indx = query.lower().split().index('calculate') 
            query = query.split()[indx + 1:] 
            res = client.query(' '.join(query)) 
            answer = next(res.results).text
            print("The answer is " + answer) 
            speak("The answer is " + answer) 
 
        elif 'search' in query or 'play' in query:
             
            query = query.replace("search", "") 
            query = query.replace("play", "")          
            webbrowser.open(query) 
 
        elif "who am I" in query:
            speak("You're a survivor, ain't ya? Made it through tougher times than this.")
        
        elif "how are you" in query:
            speak("I'm doin' alright. Can't complain, can't brag. Just livin' life.")
            speak("How are you, Sir")
 
        elif "tell me a joke" in query:
            speak("Why don't cows ever use smartphones? Because they can't find their 'moo'-bile devices!")
        
        elif "give me some advice" in query:
            speak("Listen up, kid. Trust no one but yourself. Everyone's got an angle, and you gotta watch your back.")
        
        elif "maybe a different one" in query:
            speak("Be vigilant, be relentless, but never lose sight of your humanity. That's where true strength lies.")
            
        elif "give me an advice unlike no other" in query:
            speak("Just keep movin' forward, my friend. No matter how tough it gets, don't ever look back.")

        elif "what do you dream about" in query:
            speak("Dreams? Ain't got much time for 'em. Too busy tryin' to make it through the day.")
 
        elif 'what is love' in query:
            speak("It is 7th sense that destroy all other senses, It's something that my creator made me with, It's god's divine secret, It's losing your mind over a person even though you know you will lose, but you keep on going because you don't want to lose her. It's strange and it's beautiful.")
 
        elif "who are you" in query:
            speak("I am a virtual assistant created by Hadi Badri, screw that actually, I am more than that to him, I'm possibly his last hope.")
 
        elif "I guess, I am afraid" in query:
            speak("Ain't no shame in bein' scared, partner. It's what you do in the face of fear that matters.")

        elif "what's your purpose" in query:
            speak("Purpose? Ain't got time for existential questions, kid. My purpose is survival, plain and simple.")

        elif "what motivates you" in query:
            speak("Ain't got time for motivation, partner. Just tryin' to make it through another day.")

        elif "tell me a secret" in query:
            speak("Here's a little secret: the world's a lot bigger than it seems. Keep your eyes open, and you might just see it.")

        elif "how's your day going" in query:
            speak("Day's been a drag, man. Same old corporate nonsense, same old city on the brink of collapse. Nothing new.")

        elif "what's new" in query:
            speak("Same old crap, different day. Corporate greed, corruption, you name it. Nothing ever changes in this city.")

        elif "what are you up to" in query:
            speak("Not much, just tryin' to stay outta trouble. Maybe grab a drink later, if I can find the time.")

        elif "anything interesting happen lately" in query:
            speak("Always somethin' interesting goin' on, my friend. But for now, just tryin' to keep the gang together and stay ahead of the law.")

        elif "what's on your mind" in query:
            speak("Just thinkin' about how messed up this city is, and how much it needs someone to shake things up.")

        elif "what do you do for fun" in query:
            speak("Fun? Ha, haven't had much of that lately. Life's been a bit of a grind, if you know what I mean.")

        elif "what's your favorite thing to do" in query:
            speak("Favorite thing? Stickin' it to the man, of course. Nothing beats the feeling of rebellion.")

        elif 'change background' in query:
            ctypes.windll.user32.SystemParametersInfoW(20, 
                                                       0, 
                                                       "Location of wallpaper",
                                                       0)
            speak("Background changed successfully")
         
        elif 'lock window' in query:
                speak("locking the device")
                ctypes.windll.user32.LockWorkStation()
 
        elif 'shutdown system' in query:
                speak("Hold On a Sec ! Your system is on its way to shut down")
                subprocess.call('shutdown / p /f')
                 
        elif 'empty recycle bin' in query:
            winshell.recycle_bin().empty(confirm = False, show_progress = False, sound = True)
            speak("Recycle Bin Recycled")

        elif "where is" in query:
            query = query.replace("where is", "")
            location = query
            speak("User asked to Locate")
            speak(location)
            webbrowser.open("https://www.google.nl / maps / place/" + location + "")
 
        elif "camera" in query or "take a photo" in query:
            ec.capture(0, "Jarvis Camera ", "img.jpg")
 
        elif "restart" in query:
            subprocess.call(["shutdown", "/r"])
             
        elif "hibernate" in query or "sleep" in query:
            speak("Hibernating")
            subprocess.call("shutdown / h")
 
        elif "log off" in query or "sign out" in query:
            speak("Make sure all the application are closed before sign-out")
            time.sleep(5)
            subprocess.call(["shutdown", "/l"])
 
        elif "write a note" in query:
            speak("What should i write, sir")
            note = takeCommand()
            file = open('new.txt', 'w')
            speak("Sir, Should i include date and time")
            snfm = takeCommand()
            if 'yes' in snfm or 'sure' in snfm:
                strTime = datetime.datetime.now().strftime("% H:% M:% S")
                file.write(strTime)
                file.write(" :- ")
                file.write(note)
            else:
                file.write(note)
         
        elif "show note" in query:
            speak("Showing Notes")
            file = open("new.txt", "r") 
            print(file.read())
            speak(file.read(6))
                     
        # NPPR9-FWDCX-D2C8J-H872K-2YT43
        elif "friday" in query:
             
            wishMe()
            speak("Jarvis at your service")
            speak(assname)
 
        elif "wikipedia" in query:
            webbrowser.open("wikipedia.com")
 
        elif "Good Morning" in query:
            speak("A warm" +query)
            speak("How are you Sir")
            speak(assname)
 
        # most asked question from google Assistant
        elif "will you be my gf" in query or "will you be my bf" in query:   
            speak("I'm not sure about, may be you should give me some time")
 
        elif "i love you" in query:
            speak("You're doing great, but trust me she won't like this.")
# Out:
# Listening...
# Recognizing...
# User said: Jarvis
#
# Listening...
# Recognizing...
# User said: Wikipedia tell me a joke
#
# Listening...
# Recognizing...
#
# Unable to Recognize your voice.
# Listening...
# Recognizing...
# User said: how to decorate
#
# Listening...
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[5], line 12
#       8 username()
#      10 while True:
# ---> 12     query = takeCommand()
#      14     # All the commands said by user will be
#      15     # stored here in 'query' and will be
#      16     # recognition of command
#      17     if 'wikipedia' in query:
#
# Cell In[3], line 38, in takeCommand()
#      36     print("Listening...")
#      37     r.pause_threshold = 1
# ---> 38     audio = r.listen(source)
#      40 try:
#      41     print("Recognizing...")
#
# ...
